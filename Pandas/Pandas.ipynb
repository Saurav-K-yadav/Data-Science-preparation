# %%
import pandas as pd
df=pd.read_csv('/content/pokemon_data.csv')
print(df.head(10)) # Print first 10 rows
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
print(df.tail(10))
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# ...

# %%
# Index starts at 0
# print(df.columns) #Name of columns
# print(df['Defense'].tail()) # Print last 5 rows of column defense
# print(df['Name'][0:10]) # Print first 10 rows of column name
# print(df[['Name','Attack','Defense']]) #Print three different columns

# print(df.iloc[1:4]) # Print rows 1 to 3 i.e. start->(end-1)
# print(df.iloc[2,1]) #Row no 2, column no 1

# for index,row in df.iterrows():# Iterate through the each row while index starts at 0 and goes i+1 every round
#   print(index,row[['Name','Attack']])

# df.loc[df['Type 1'] == 'Fire'] # used for non-interger based listing

# %% [markdown]
# ### SORTING AND DESCRIBING DATA

# %%
# df.describe() #Statistical description of data
# df.sort_values(['Attack','Name'],ascending=[False,True]) #Sort on descending order of attack then name

# %% [markdown]
# #### Making Changes to Data

# %%
df['Total'] = df['HP']+df['Attack']+df['Defense']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    143
# 1       80     60           1      False    185
# 2      100     80           1      False    245
# 3      120     80           1      False    303
# 4       50     65           1      False    134

# %%
# df=df.drop(columns=['Total'])
# df['Total']=df.iloc[:,4:10].sum(axis=1)
# df.head()
cols=list(df.columns)
# print(cols)
df=df[cols[0:4]+[cols[-1]]+cols[4:12]]
df.head(5)
# df = df[['Total']]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    143  45      49       49
# 1  2                Ivysaur  Grass  Poison    185  60      62       63
# 2  3               Venusaur  Grass  Poison    245  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    303  80     100      123
# 4  4             Charmander   Fire     NaN    134  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# df.to_csv('modified_pokemons.csv',index=False)

# %% [markdown]
# ### Filtering Data

# %%
new_df=df.loc[(df['Type 1']=='Grass') & (df['Type 2'] == 'Poison')&(df['HP']>7)]
new_df.reset_index(drop=True,inplace=True)
new_df
# Out:
#       #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0     1              Bulbasaur  Grass  Poison    143   45      49       49
# 1     2                Ivysaur  Grass  Poison    185   60      62       63
# 2     3               Venusaur  Grass  Poison    245   80      82       83
# 3     3  VenusaurMega Venusaur  Grass  Poison    303   80     100      123
# 4    43                 Oddish  Grass  Poison    150   45      50       55
# 5    44                  Gloom  Grass  Poison    195   60      65       70
# 6    45              Vileplume  Grass  Poison    240   75      80       85
# 7    69             Bellsprout  Grass  Poison    160   50      75       35
# 8    70             Weepinbell  Grass  Poison    205   65      90       50
# 9    71             Victreebel  Grass  Poison    250   80     105       65
# 10  315                Roselia  Grass  Poison    155   50      60       45
# ...

# %% [markdown]
# ### Filter out names containing mega

# %%
# df.loc[df['Name'].str.contains('Mega')]
import re
# df.loc[df['Type 1'].str.contains('fire|grass',flags=re.IGNORECASE,regex=True)]
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    125   40      45
# 21    17            Pidgeotto    Normal    Flying    178   63      60
# 22    18              Pidgeot    Normal    Flying    238   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    243   83      80
# 30    25              Pikachu  Electric       NaN    130   35      55
# 136  127               Pinsir       Bug       NaN    290   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    340   65     155
# 186  172                Pichu  Electric       NaN     75   20      40
# 219  204               Pineco       Bug       NaN    205   50      65
# 239  221            Piloswine       Ice    Ground    280  100     100
# 438  393               Piplup     Water       NaN    157   53      51
# 558  499              Pignite      Fire  Fighting    238   90      93
# ...

# %%
### Conditional Changes

# %%
# df.loc[df['Type 1']=='Fire']
# type(df['Type 1']=='Fire')
# df.loc[df['Type 1']=='Fire','Type 1']
# df.loc[df['Type 2']=='Flying',['Total','HP']]=0
# df.loc[df['Type 2']=='Flying']

# %% [markdown]
# ### Aggregate Statistics (GroupBy)

# %%
# df=pd.read_csv('/content/pokemon_data.csv')
# df
# df.groupby(['Type 1']).mean(numeric_only=True).sort_values(['Attack'],ascending=False).loc[:,'Attack']
# df['Count']=1
# df.groupby(['Type 1']).count()
# df.groupby(['Type 1','Type 2']).count()
